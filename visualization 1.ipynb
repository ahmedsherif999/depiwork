# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv(r"Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head(20).plot(kind = 'bar',subplots = True)
# Out:
# array([<Axes: title={'center': 'Survived'}, xlabel='PassengerId'>,
#        <Axes: title={'center': 'Pclass'}, xlabel='PassengerId'>,
#        <Axes: title={'center': 'Age'}, xlabel='PassengerId'>,
#        <Axes: title={'center': 'SibSp'}, xlabel='PassengerId'>,
#        <Axes: title={'center': 'Parch'}, xlabel='PassengerId'>,
#        <Axes: title={'center': 'Fare'}, xlabel='PassengerId'>],
#       dtype=object)

# %%
f = df['Fare']
f
# Out:
# PassengerId
# 892       7.8292
# 893       7.0000
# 894       9.6875
# 895       8.6625
# 896      12.2875
#           ...
# 1305      8.0500
# 1306    108.9000
# 1307      7.2500
# 1308      8.0500
# 1309     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
f.plot(kind = 'line')
plt.title('fare for each passenger')
plt.xlabel('passenger id')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
a = df['Age']
a
# Out:
# PassengerId
# 892     34.5
# 893     47.0
# 894     62.0
# 895     27.0
# 896     22.0
#         ...
# 1305     NaN
# 1306    39.0
# 1307    38.5
# 1308     NaN
# 1309     NaN
# Name: Age, Length: 418, dtype: float64

# %%
a.plot(kind = 'hist')
plt.title('age of people on the titanic')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
e = df['Embarked'].value_counts()
e
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
e.plot(kind = 'pie')
plt.title('embarked places')
# Out:
# Text(0.5, 1.0, 'embarked places')

# %%
p = df['Pclass'].value_counts()
p
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
p.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df_pclass = df.groupby('Pclass').sum()
df_pclass
# Out:
#         Survived                                               Name  \
# Pclass
# 1             50  Jones, Mr. Charles CressonSnyder, Mrs. John Pi...
# 2             30  Myles, Mr. Thomas FrancisCaldwell, Mr. Albert ...
# 3             72  Kelly, Mr. JamesWilkes, Mrs. James (Ellen Need...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       malefemalefemalemalefemalemalefemalefemalemale...  4010.00     51
# 2       malemalemalefemalemalemalemalefemalemalefemale...  2532.42     35
# 3       malefemalemalefemalemalefemalefemalemalemalema...  3508.08    101
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          41  69421228W.E.P. 5734PC 17603PC 17598PC 17597PC ...  10087.9918
# 2          32  24027624873824065SC/PARIS 2167233734SC/AH 3085...   2064.7957
# 3          91  330911363272315154310129875383309722657A/4 488...   2703.7501
#
# ...

# %%
surv = df_pclass['Survived']
surv
# Out:
# Pclass
# 1    50
# 2    30
# 3    72
# Name: Survived, dtype: int64

# %%
surv.plot(kind = 'bar')

plt.ylabel('survivals per class')
# Out:
# Text(0, 0.5, 'survivals per class')

# %%
ff = df_pclass['Fare']
ff
# Out:
# Pclass
# 1    10087.9918
# 2     2064.7957
# 3     2703.7501
# Name: Fare, dtype: float64

# %%
ff.plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter' , x = 'Name' , y ='Age')
# Out:
# <Axes: xlabel='Name', ylabel='Age'>

# %%
print(df.columns)
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
